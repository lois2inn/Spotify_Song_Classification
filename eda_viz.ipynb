# %% [markdown]
# ## Coding Best Practices
# **Use descriptive and meaningful variable names**: Avoid using generic variable names like x, y, and z. Instead, choose names that are descriptive and indicate the purpose or content of the variable or function. This makes the code more readable and easier to understand.
#
# **Use lowercase letters**: In Python, variable and function names should start with a lowercase letter. This is a convention that is widely used and makes it easy to distinguish between variables/functions and classes.
#
# **Use underscores for readability**: Use underscores to separate words in a variable or function name. This makes the name more readable and easier to understand.
#
# **Avoid using reserved keywords**: Avoid using Python's reserved keywords, such as "if", "else", "while", "for", etc. as variable or function names.
#
# **Use camel case for class names**: In Python, class names should start with a capital letter and use camel case. For example, MyClass. This is to distinguish individual words within a compound name.
#
# **Be consistent**: Be consistent with naming conventions throughout your code. If you choose to use underscores to separate words in variable names, use the same convention throughout your code.
#
# **Avoid abbreviations**: Avoid using abbreviations unless they are widely understood in the context of your code. Abbreviations can make code harder to understand.
#
# **Keep function names concise**: Keep function names concise and to the point. A good function name should describe what the function does in a single word or phrase.
#
# **Use singular nouns for variables**: Use singular nouns for variables. For example, use "customer" instead of "customers" if you are referring to a single customer.
#
# **Inline comments**: Comment code using # for easier readability. Use comments to explain your process and reasoning to track your work and for others to follow along.

# %% [markdown]
# ## Load data

# %%
# Import statements for libraries needed
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data from csv 
raw_df = pd.read_csv("Resources/data.csv")
raw_df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %% [markdown]
# ## Data Overview

# %%
# Concise summary of the data contained within the DataFrame
# i.e. The total number of entries (rows) in the DataFrame, data type of each column, 
# number of non-null values in each column, amount of memory used by the DataFrame.
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
# Generate descriptive statistics of a DataFrame
# It provides a summary of the central tendency, dispersion, and shape of the distribution of a dataset.
raw_df.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# ...

# %%
# Get the first 10 rows of the dataframe
raw_df.head(10)
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0       0.01020         0.833       204600   0.434
# 1           1       0.19900         0.743       326933   0.359
# 2           2       0.03440         0.838       185707   0.412
# 3           3       0.60400         0.494       199413   0.338
# 4           4       0.18000         0.678       392893   0.561
# 5           5       0.00479         0.804       251333   0.560
# 6           6       0.01450         0.739       241400   0.472
# 7           7       0.02020         0.266       349667   0.348
# 8           8       0.04810         0.603       202853   0.944
# 9           9       0.00208         0.836       226840   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# ...

# %%
# View the shape of the data: the rows and the columns
raw_df.shape
# Out:
# (2017, 17)

# %%
# Check whether there are any null (NaN) values
raw_df.isnull().values.any()
# Out:
# False

# %%
# Aside from the code above, you can also use sum()
raw_df.isnull().sum()
# Out:
# Unnamed: 0          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
# The below will sum the total null values in the dataframe.
raw_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## How to handle null values?
#
# **Analyze the pattern**: Investigate the reason behind null values to determine if they are random or systematic, which may affect the chosen method.
#
# **Remove missing data**: In cases of limited null values, dropping rows or columns with missing data can be a viable solution, using functions like dropna() in pandas.
#
# **Impute values**: Replace missing data with estimated values based on available data, such as mean, median, or mode imputation, or more advanced techniques like k-Nearest Neighbors (KNN) or regression imputation.
#
# **Use categorical placeholders**: For categorical variables, consider introducing a new category (e.g., "Unknown") to represent missing data.
#
# **Incorporate uncertainty**: Utilize probabilistic models or Bayesian techniques to account for uncertainty arising from missing data, allowing for more robust analyses and conclusions.

# %%
# Check if there are duplicated values in the data
raw_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## How to handle duplicates?
#
# - Check if those values are unique in each columns, if they are unique and relevant for the analysis, keep the data.
#
# - If the data is duplicated then drop it to avoid bias in the analysis.

# %%
# Check for outliers
raw_df.skew(numeric_only=True)
# Out:
# Unnamed: 0          0.000000
# acousticness        1.658393
# danceability       -0.419610
# duration_ms         2.499012
# energy             -0.913010
# instrumentalness    1.952755
# key                -0.009360
# liveness            1.952703
# loudness           -2.226556
# mode               -0.461301
# speechiness         2.309581
# tempo               0.439058
# time_signature     -2.234521
# valence             0.078390
# target             -0.022825
# dtype: float64

# %%
# Get statistical description of numerical variable in dataframe
raw_df['energy'].describe()
# Out:
# count    2017.000000
# mean        0.681577
# std         0.210273
# min         0.014800
# 25%         0.563000
# 50%         0.715000
# 75%         0.846000
# max         0.998000
# Name: energy, dtype: float64

# %%
# Display unique values of a categorical variable
raw_df.artist.unique()
# Out:
# array(['Future', 'Childish Gambino', 'Beach House', ..., 'Rain Man',
#        'Twin Moons', 'Bleachers'], dtype=object)

# %%
# Display the number of unique artists
raw_df.artist.nunique()
# Out:
# 1343

# %%
# Get a list of unique categorical variables
display(raw_df['artist'].unique().tolist())
# Out:
# ['Future',
#  'Childish Gambino',
#  'Beach House',
#  'Junior Boys',
#  'Drake',
#  'Omega',
#  'Death Grips',
#  'Honey Claws',
#  'The Avalanches',
#  'Modern Folk Üçlüsü',
#  'Erkin Koray',
#  'Lil Yachty',
#  'PNL',
#  'Crystal Castles',
#  'New Order',
#  'Funkadelic',
#  'Chief Keef',
#  'Le Youth',
#  'Cajmere',
#  'The Rapture',
#  'Young Thug',
#  'Ty Segall',
#  'Myron & E',
#  'TR/ST',
#  'A-Trak',
#  'Rae Sremmurd',
#  'Father',
#  '2milly',
#  'Ty Dolla $ign',
#  'Santigold',
#  'Three 6 Mafia',
#  'Beyoncé',
#  'Rockwell',
#  'Disclosure',
#  'ILoveMakonnen',
#  'Riff Raff',
#  'Kanye West',
#  'Young M.A.',
#  'Mark Morrison',
#  'William Onyeabor',
#  'Dr. John',
#  'T. P. Orchestre Poly-Rythmo',
#  'Ebo Taylor',
#  'Neon Indian',
#  'Future Islands',
#  'Leon Bridges',
#  'Post Malone',
#  'Jamie xx',
#  'A$AP Rocky',
#  'Vince Staples',
#  'Best Coast',
#  "Ariel Pink's Haunted Graffiti",
#  'Bobby "Blue" Bland',
#  'Yacht Club',
#  'Portugal. The Man',
# ...

# %%
#  Get the top occurances of an 'artist' in the dataset
raw_df.groupby('artist').filter(lambda g: (g.nunique() > 10).any())
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 5              5      0.004790         0.804       251333   0.560
# 6              6      0.014500         0.739       241400   0.472
# 37            37      0.056500         0.853       205879   0.547
# 40            40      0.000410         0.731       324541   0.852
# 102          102      0.247000         0.525       292760   0.643
# 117          117      0.002570         0.896       267024   0.623
# 123          123      0.000758         0.695       253773   0.912
# 133          133      0.066800         0.704       199246   0.647
# 154          154      0.001570         0.790       217707   0.676
# 158          158      0.190000         0.735       275840   0.410
# 168          168      0.047200         0.849       217693   0.408
# 174          174      0.037000         0.807       250130   0.785
# 180          180      0.010700         0.882       284027   0.743
# ...

# %% [markdown]
# ## Data Visualization and Distribution
# ### Attributes: Numerical (Continuous and Discrete)
# - **Acousticness**: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# - **Danceability**: describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# - **Energy**: A measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# - **Instrumentalness**: Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# - **Liveness**: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# - **Loudness**: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
# - **Speechiness**: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# - **Tempo**: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# - **Valence**: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# - **Target**: The song popularity. Like it or not.

# %%
continuous_cols = ['acousticness', 'danceability', 'energy',
                   'liveness', 'loudness',  'tempo',  'valence', 'speechiness', 'instrumentalness']
discrete_cols = ['key','mode','time_signature','target']

# %%
sns.set_palette("rainbow_r")
fig, axes = plt.subplots(3,3,figsize=(15,20))
axes = axes.flatten()
ax_no = 0
num_cols = continuous_cols
for col in num_cols:
    sns.histplot(data = raw_df, x=col, bins=25, kde=True, ax = axes[ax_no])
    ax_no += 1
plt.show()

# %%
sns.set_style('darkgrid')
sns.set_context('paper', font_scale=1.2)

# %%
fig, axes = plt.subplots(3,3,figsize=(15,20))
palettes = ['viridis','Set1', 'prism', 'rocket']
axes = axes.flatten()
ax_no = 0
for col in continuous_cols:
    sns.set_palette(palettes[ax_no%4])
    sns.histplot(data = raw_df, x=col, hue='target', bins=25, kde=True, ax = axes[ax_no])
    ax_no += 1
fig.suptitle('Distributions of Continuous Features')
plt.show()

# %%
sns.set_palette("Set1")
fig, axes = plt.subplots(2,2,figsize=(16,10))
palettes = ['tab10', 'Paired', 'rocket', 'Set1']
axes = axes.flatten()
ax_no = 0
for col in discrete_cols:
    sns.set_palette(palettes[ax_no%4])
    sns.countplot(data = raw_df, x= col, ax = axes[ax_no], hue='target')
    ax_no += 1
fig.suptitle('Distributions of Discrete Features')
plt.show()

# %%
plt.figure(figsize=(25,8))
sns.swarmplot(x='target', y='danceability', data=raw_df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='danceability'>

# %%
plt.figure(figsize=(25,8))
sns.swarmplot(x='target', y='loudness', data=raw_df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='loudness'>

# %%
sns.set_theme(style="whitegrid")

cmap = sns.light_palette((20, 60, 50), input="husl")
g = sns.relplot(
    data=raw_df,
    x="energy", y="danceability",
    hue="target", size="tempo",
    palette='husl'
)

# %%
plt.figure(figsize=(25,8))
sns.swarmplot(x='target', y='energy', data=raw_df, hue = 'target')
# Out:
# <AxesSubplot:xlabel='target', ylabel='energy'>

# %%
sns.set_theme(style="whitegrid")

# Draw a pointplot to show pulse as a function of three categorical factors
g = sns.catplot(
    data=raw_df, x="mode", y="key", hue="time_signature", col="target",
    capsize=.2, palette="rocket", errorbar="se",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)

# %%
plt.figure(figsize=(25,8))
sns.displot(raw_df, x="danceability", hue="key", kind="kde")

# %%
sns.relplot(
    data=raw_df, kind="line",
    x="mode", y="key", hue="target",
    sort=False
)

# %%
sns.relplot(
    data=raw_df, kind="line",
    x="mode", y="energy", hue="target",
    sort=False
)

# %%
sns.relplot(
    data=raw_df, kind="line",
    x="mode", y="danceability", hue="target",
    sort=False
)
